# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
dataset=pd.read_csv(r"C:\Users\it solution\Downloads\Compressed\archive (12)\Linear.csv")
dataset.head(4)
# Out:
#    X         Y
# 0  1  3.888889
# 1  2  4.555556
# 2  3  5.222222
# 3  4  5.888889

# %%
dataset.isnull().sum()
# Out:
# X    0
# Y    0
# dtype: int64

# %%
sns.scatterplot(x="X", y="Y", data=dataset)
plt.show()

# %%
x=dataset[["X"]]
y=dataset["Y"]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.svm import SVR

# %%
sv=SVR(kernel='linear')
sv.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
sv.score(x_test, y_test), sv.score(x_train, y_train)
# Out:
# (0.9999989496231771, 0.8985154421149578)

# %%
sv.predict([[4]])
# Out:
# C:\Users\it solution\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([5.98684111])

# %%
# kernel : {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
df={"kernel":['linear', 'poly', 'rbf', 'sigmoid'],
    "degree":[i for i in range(2, 20)],
    "gamma":['scale', 'auto']
    
}

# %%
gd=GridSearchCV(SVR, param_grid=df)
gd.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 gd=GridSearchCV(SVR, param_grid=df)
# ----> 2 gd.fit(x_train, y_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:812, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     809 cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
# ...

# %%
gd.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 gd.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
sns.scatterplot(x="X", y="Y", data=dataset)
plt.scatter(dataset["X"], sv.predict(x), color="red")
plt.show()

# %%
import numpy as np

# %%
plot_decision_regions(x.to_numpy(), y.astype(np.int_).to_numpy(), clf=sv)
plt.show()
# Out:
# C:\Users\it solution\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# C:\Users\it solution\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlxtend\plotting\decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
